# %%
import os
import cv2
from deepface import DeepFace
from deepface.commons import functions
import numpy as np
import matplotlib.pyplot as plt
import matplotlib 
from time import time

# Local descriptors
from skimage.feature import hog, local_binary_pattern
from skimage import  exposure
from skimage import feature

# Classifiers
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier 
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Definición de funciones
#
# lbphist Definido un número de celdas, calcula el histograma LBP de cada una, concatenando los histogramas resultantes
#
#
# GetPredictions y GetPredictionsandProbs obtienen las etiquetas o probabulidades paar un conjunto de test.

# %%
def lbphist(ncellsx, ncellsy, type):
    #Rejilla de histogramas
    pxpercellx = int(width/ncellsx)
    pxpercelly = int(height/ncellsy)

    # Rejillas de igual tamaño y centradas en la imagen de entrada
    ofx = int((width - int(pxpercellx)*ncellsx)/2)
    ofy = int((height - int(pxpercelly)*ncellsy)/2)
    #print('Offset')
    #print(ofx,ofy)

    Xlbp = []

    LBPu_hist = []
    for i in range(0,ncellsy):
        for j in range(0,ncellsx):
            # Extrae celda
            roi=gray[ofy+i*pxpercelly:ofy+(i+1)*pxpercelly,ofx+j*pxpercellx:ofx+(j+1)*pxpercellx]
            # Obtiene imagen LBO
            lbpimg = feature.local_binary_pattern(roi, 8, 1,method=type)
            
            #Obtiene histograma
            n_bins = int(lbpimg.max()) + 1            
            #feath, bins = np.histogram(lbpimg.ravel(), normed=True, bins=n_bins, range=(0,n_bins))
            feath, bins = np.histogram(lbpimg, normed=False, bins=n_bins, range=(0,n_bins))
            
            # Concatena con celdas previas
            LBPu_hist= np.concatenate([LBPu_hist , feath])
            
    return LBPu_hist

# %%
def GetPredictions(X_train, X_test, y_train, y_test, model, parameters):
    model_name = type(model).__name__
    print(f"{model_name} Normalization...")
    scaler = MinMaxScaler()
    train_X = scaler.fit_transform(X_train)
    test_X = scaler.transform(X_test)

    print(f"{model_name} training...")
    t0 = time()
    
    # Grid searach across parameter range
    clf = GridSearchCV(model, parameters, cv=5)
    clf = clf.fit(train_X, y_train)
    print("done in %0.3fs" % (time() - t0))
    print("Best estimator found by grid search:")
    print(clf.best_estimator_)

    print("Predicting")
    t0 = time()
    # test labels
    y_pred = clf.predict(test_X)
   
    print("done in %0.3fs" % (time() - t0))
    
    return y_pred, y_test

def GetPredictionsandProbs(X_train, X_test, y_train, y_test):
    
    print("SVM Normalization...")
    scaler = MinMaxScaler()
    train_X = scaler.fit_transform(X_train)
    test_X = scaler.transform(X_test)

    print("SVM training...")
    t0 = time()
    parameters = {'C': [1e3, 5e3],
                  'gamma': [0.0001, 0.0005, 0.001, 0.005, 0.01],}
    # Grid search across parameter range
    clf = GridSearchCV(
        SVC(kernel='rbf', class_weight='balanced', probability=True), parameters, cv=5
    )
    clf = clf.fit(train_X, y_train)
    print("done in %0.3fs" % (time() - t0))
    print("Best estimator found by grid search:")
    print(clf.best_estimator_)

    print("Predicting")
    t0 = time()
    # test labels
    y_pred = clf.predict(test_X)
    
    # train and test class probabilities
    ytrain_prob = clf.predict_proba(train_X)
    ytest_prob = clf.predict_proba(test_X)
    
    print("done in %0.3fs" % (time() - t0))
    
    return y_pred, y_test, ytrain_prob, ytest_prob

# %%
def calc_embs(model, X, batch_size=2):
    norm_images = prewhiten(X)
    pd = []
    for start in range(0, len(norm_images), batch_size):
        pd.append(model.predict_on_batch(norm_images[start:start+batch_size]))
    return l2_normalize(np.concatenate(pd))

def l2_normalize(x, axis=-1, epsilon=1e-10):
    output = x / np.sqrt(np.maximum(np.sum(np.square(x), axis=axis, keepdims=True), epsilon))
    return output

def prewhiten(x):
    if x.ndim == 4:
        axis = (1, 2, 3)
        size = x[0].size
    elif x.ndim == 3:
        axis = (0, 1, 2)
        size = x.size
    else:
        raise ValueError('Dimension should be 3 or 4')

    mean = np.mean(x, axis=axis, keepdims=True)
    std = np.std(x, axis=axis, keepdims=True)
    std_adj = np.maximum(std, 1.0/np.sqrt(size))
    y = (x - mean) / std_adj
    return y

# %% [markdown]
# # Carga conjunto de datos
#
# Se proporciona la carpeta, a través de la variable folder, donde cada subcarpeta se corresponde con una clase.
# Cada clase contiene muestras en forma de imágenes jpg, todas del mismo tamaño

# %%
# Deepface
# Modelos disponibles ['VGG-Face', 'Facenet', 'OpenFace', 'DeepFace', 'DeepID', 'Dlib']
model_deepface = DeepFace.build_model("Facenet")
target_size = model_deepface.layers[0].input_shape[0]
dim = (int(target_size[1]), int(target_size[2]))

# Localización de los datos
folder = "Database_real_and_fake_face_160x160"
# Contador de número de clases del conjunto
nclasses = 0
# Contador de muestras por clase
nperclass = []
# Etiqueta de cada clase (nombre de la subcarpeta)
classlabels = []
# Inicializa estructuras de datos y sus correpondientes etiquetas
X = []
Y = []
Xhog = []
XLBP = []
XFaceNet = []

# Valor de resolución por defecto de matplotlib
dpi = matplotlib.rcParams['figure.dpi']
# Imágenes de muestra de cada clase a mostrar
nims2show = 5

# HOG
ncellsx = 3
ncellsy = 3

# Asume que en la ruta indicada hay una subcarpeta por clase
for class_name in os.listdir(folder):
    # Cada subcarpeta implica una clase más
    nclasses += 1
    # Inicialmente esta clase no tiene muestras
    nsamples = 0    

    # Compone la ruta
    class_folder = os.path.join(folder, class_name)
    for file_name in os.listdir(class_folder):
        # Asume imágenes en formato jpg
        if file_name.endswith('.jpg'):
            # Lee la imagen
            image = cv2.imread (os.path.join(class_folder, file_name))
            
            # Extrae tamaños
            height, width, depth = image.shape
            # Convierte  grises
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            # Añade a X, previa conversión en vector
            X.append(gray.reshape(height*width))
            
            # HOG            
            feat_hog, hog_image = hog(gray, orientations=8, pixels_per_cell=(height/ncellsy, width/ncellsx),
                    cells_per_block=(1, 1), visualize=True, multichannel=False, block_norm='L1')
            Xhog.append(feat_hog)
            # print(len(Xhog))  
            
            # Local binary pattern
            feat_lbp = lbphist(ncellsx, ncellsy, 'nri_uniform')
            XLBP.append(feat_lbp)
            
            # Deepface con FaceNet
            # Obtiene embeddings
            img_embedding = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
            img_embedding = calc_embs(model_deepface, np.array([img_embedding]))
            XFaceNet.append(img_embedding[0])
                    
            # Añade etiqueta numérica de la muestra
            Y.append(nclasses-1)
            
            # Muestra las nims2show primeras muestras de cada clase
            if nsamples < nims2show:
                if nsamples == 0:                    
                    figsize = 15*width / float(dpi), 15*height / float(dpi)
                    fig = plt.figure(figsize=figsize)                
                
                fig.add_subplot(1,nims2show, nsamples + 1)
                plt.imshow(gray, cmap='gray', vmin=0, vmax=255)                
                
            #Incrementa el número de muestras
            nsamples += 1
    plt.show()
    nperclass.append(nsamples)
    classlabels.append(class_name)
    
#Convierte a numpy array X e Y
X = np.array(X,dtype='float32')
Y = np.array(Y,dtype='float64')
Xhog = np.array(Xhog,dtype='float32')
XLBP = np.array(XLBP,dtype='float32')
XFaceNet = np.array(XFaceNet,dtype='float32')

# Muestra datos del conjunto leído
# Depuración
print("Features")
print(X.shape)
print(Xhog.shape)
print(XLBP.shape)
print(XFaceNet.shape)
print(Y.shape)
# Obtiene número de muestras y características
n_samples , n_features = X.shape
# Obtiene nombres de las clases
class_names = np.array(classlabels)
n_classes = class_names.shape[0]

print("Dataset info:")
print("# samples: %d" % n_samples)
print("# features: %d" % n_features)
print("# classes: %d" % n_classes)
print("classes %s" % classlabels)
print("samples per class %s" % str(nperclass)[1:-1] )
# Out:
# Features
# (2041, 25600)
# (2041, 32)
# (2041, 531)
# (2041, 128)
# (2041,)
# Dataset info:
# # samples: 2041
# # features: 25600
# # classes: 2
# classes ['fake', 'real']
# samples per class 960, 1081

# %% [markdown]
# # Diseña conjunto experimental k-fold
#
# Divide los datos k veces en conjunto de entrenamiento y test

# %%
# StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=7, shuffle=True)

fold = 1
for train_index, test_index in skf.split(X, Y):
    #print("TRAIN:", train_index, "TEST:", test_index)
    print("Fold %d" % fold)
    print("# samples in training set %d" % train_index.shape[0])
    print("# samples in test set %d" % test_index.shape[0])
    fold += 1
# Out:
# Fold 1
# # samples in training set 1632
# # samples in test set 409
# Fold 2
# # samples in training set 1633
# # samples in test set 408
# Fold 3
# # samples in training set 1633
# # samples in test set 408
# Fold 4
# # samples in training set 1633
# # samples in test set 408
# Fold 5
# # samples in training set 1633
# # samples in test set 408

# %% [markdown]
# # Para cada fold
#
# Obtiene resultados con HOG y LBP. Además entrena un clasificador basado por fusión de scores (score level fusion) de los obtenidos de los clasificadores previos.

# %%
print("+++++++++++++++++++++++++++++++++++++++++++\n")

# KNN 
precs_hog_svm, recs_hog_svm, acc_hog_svm = [], [], []
precs_lbp_svm, recs_lbp_svm, acc_lbp_svm = [], [], []
precs_facenet_svm, recs_facenet_svm, acc_facenet_svm = [], [], []

precs_hog_rf, recs_hog_rf, acc_hog_rf = [], [], []
precs_lbp_rf, recs_lbp_rf, acc_lbp_rf = [], [], []
precs_facenet_rf, recs_facenet_rf, acc_facenet_rf = [], [], []

precs_hog_mlp, recs_hog_mlp, acc_hog_mlp = [], [], []
precs_lbp_mlp, recs_lbp_mlp, acc_lbp_mlp = [], [], []
precs_facenet_mlp, recs_facenet_mlp, acc_facenet_mlp = [], [], []


SVM = SVC(kernel='rbf', class_weight='balanced')
SVM_parameters = {
    'C': [1e3, 5e3],
    'gamma': [0.0001, 0.0005, 0.001, 0.005, 0.01],
}

RF = RandomForestClassifier()
RF_parameters = {
    'n_estimators': [100, 150, 200],
}

MLP = MLPClassifier()
MLP_parameters = {
    'hidden_layer_sizes': [100, 150, 200],
    'solver': ['lbfgs', 'sgd', 'adam'],
    'max_iter': [200, 250, 300, 350, 400]
}

fold = 1
for train_index, test_index in skf.split(X, Y):
    #print("TRAIN:", train_index, "TEST:", test_index)
    print("*********************\nFold %d" % fold)
    
    #HOG
    print("\nHOG")
    y_pred, y_test = GetPredictions(Xhog[train_index], Xhog[test_index],Y[train_index], Y[test_index], SVM, SVM_parameters)
    print("\nHOG + SVM Metrics")
    precs_hog_svm.append(precision_score(y_test, y_pred))
    recs_hog_svm.append(recall_score(y_test, y_pred))
    acc_hog_svm.append(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred, target_names=class_names))
    if fold == 1:
        print("Confussion matrix:")
        print(confusion_matrix(y_test, y_pred, labels=range(n_classes)))
        
    y_pred, y_test = GetPredictions(Xhog[train_index], Xhog[test_index],Y[train_index], Y[test_index], RF, RF_parameters)
    print("\nHOG + RF Metrics")
    precs_hog_rf.append(precision_score(y_test, y_pred))
    recs_hog_rf.append(recall_score(y_test, y_pred))
    acc_hog_rf.append(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred, target_names=class_names))
    if fold == 1:
        print("Confussion matrix:")
        print(confusion_matrix(y_test, y_pred, labels=range(n_classes)))
        
    y_pred, y_test = GetPredictions(Xhog[train_index], Xhog[test_index],Y[train_index], Y[test_index], MLP, MLP_parameters)
    print("\nHOG + MLP Metrics")
    precs_hog_mlp.append(precision_score(y_test, y_pred))
    recs_hog_mlp.append(recall_score(y_test, y_pred))
    acc_hog_mlp.append(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred, target_names=class_names))
    if fold == 1:
        print("Confussion matrix:")
        print(confusion_matrix(y_test, y_pred, labels=range(n_classes)))
        
    #LBP
    print("\nLBP")
    y_pred, y_test = GetPredictions(XLBP[train_index], XLBP[test_index],Y[train_index], Y[test_index], SVM, SVM_parameters)
    print("\nLBP + SVM Metrics")
    precs_lbp_svm.append(precision_score(y_test, y_pred))
    recs_lbp_svm.append(recall_score(y_test, y_pred))
    acc_lbp_svm.append(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred, target_names=class_names))
    if fold == 1:
        print("Confussion matrix:")
        print(confusion_matrix(y_test, y_pred, labels=range(n_classes)))
        
    y_pred, y_test = GetPredictions(XLBP[train_index], XLBP[test_index],Y[train_index], Y[test_index], RF, RF_parameters)
    print("\nLBP + RF Metrics")
    precs_lbp_rf.append(precision_score(y_test, y_pred))
    recs_lbp_rf.append(recall_score(y_test, y_pred))
    acc_lbp_rf.append(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred, target_names=class_names))
    if fold == 1:
        print("Confussion matrix:")
        print(confusion_matrix(y_test, y_pred, labels=range(n_classes))) 
        
    y_pred, y_test = GetPredictions(XLBP[train_index], XLBP[test_index],Y[train_index], Y[test_index], MLP, MLP_parameters)
    print("\nLBP + MLP Metrics")
    precs_lbp_mlp.append(precision_score(y_test, y_pred))
    recs_lbp_mlp.append(recall_score(y_test, y_pred))
    acc_lbp_mlp.append(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred, target_names=class_names))
    if fold == 1:
        print("Confussion matrix:")
        print(confusion_matrix(y_test, y_pred, labels=range(n_classes))) 
        
    #Deepface
    print("\nDeepface/Facenet")
    y_pred, y_test = GetPredictions(XFaceNet[train_index], XFaceNet[test_index],Y[train_index], Y[test_index], SVM, SVM_parameters)
    print("\nDeepface/Facenet + SVM Metrics")
    precs_facenet_svm.append(precision_score(y_test, y_pred))
    recs_facenet_svm.append(recall_score(y_test, y_pred))
    acc_facenet_svm.append(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred, target_names=class_names))
    if fold == 1:
        print("Confussion matrix:")
        print(confusion_matrix(y_test, y_pred, labels=range(n_classes)))
        
    y_pred, y_test = GetPredictions(XFaceNet[train_index], XFaceNet[test_index],Y[train_index], Y[test_index], RF, RF_parameters)
    print("\nDeepface/Facenet + RF Metrics")
    precs_facenet_rf.append(precision_score(y_test, y_pred))
    recs_facenet_rf.append(recall_score(y_test, y_pred))
    acc_facenet_rf.append(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred, target_names=class_names))
    if fold == 1:
        print("Confussion matrix:")
        print(confusion_matrix(y_test, y_pred, labels=range(n_classes))) 
        
    y_pred, y_test = GetPredictions(XFaceNet[train_index], XFaceNet[test_index],Y[train_index], Y[test_index], MLP, MLP_parameters)
    print("\nDeepface/Facenet + MLP Metrics")
    precs_facenet_mlp.append(precision_score(y_test, y_pred))
    recs_facenet_mlp.append(recall_score(y_test, y_pred))
    acc_facenet_mlp.append(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred, target_names=class_names))
    if fold == 1:
        print("Confussion matrix:")
        print(confusion_matrix(y_test, y_pred, labels=range(n_classes))) 
        
    fold += 1

print("\n********K-FOLD SUMMARY*********")
print("HOG+SVM Mean Precision:  %0.3f, Mean Recall:  %0.3f, Mean Accuracy:  %0.3f" % ( np.mean(precs_hog_svm) , np.mean(recs_hog_svm) , np.mean(acc_hog_svm) ))
print("LBP+SVM Mean Precision:  %0.3f, Mean Recall:  %0.3f, Mean Accuracy:  %0.3f" % ( np.mean(precs_lbp_svm) , np.mean(recs_lbp_svm) , np.mean(acc_lbp_svm) ))
print("Facenet+SVM Mean Precision:  %0.3f, Mean Recall:  %0.3f, Mean Accuracy:  %0.3f" % ( np.mean(precs_facenet_svm) , np.mean(recs_facenet_svm) , np.mean(acc_facenet_svm) ))
print("HOG+RF Mean Precision:  %0.3f, Mean Recall:  %0.3f, Mean Accuracy:  %0.3f" % ( np.mean(precs_hog_rf) , np.mean(recs_hog_rf) , np.mean(acc_hog_rf) ))
print("LBP+RF Mean Precision:  %0.3f, Mean Recall:  %0.3f, Mean Accuracy:  %0.3f" % ( np.mean(precs_lbp_rf) , np.mean(recs_lbp_rf) , np.mean(acc_lbp_rf) )) 
print("Facenet+RF Mean Precision:  %0.3f, Mean Recall:  %0.3f, Mean Accuracy:  %0.3f" % ( np.mean(precs_facenet_rf) , np.mean(recs_facenet_rf) , np.mean(acc_facenet_rf) ))
print("HOG+MLP Mean Precision:  %0.3f, Mean Recall:  %0.3f, Mean Accuracy:  %0.3f" % ( np.mean(precs_hog_mlp) , np.mean(recs_hog_mlp) , np.mean(acc_hog_mlp) ))
print("LBP+MLP Mean Precision:  %0.3f, Mean Recall:  %0.3f, Mean Accuracy:  %0.3f" % ( np.mean(precs_lbp_mlp) , np.mean(recs_lbp_mlp) , np.mean(acc_lbp_mlp) )) 
print("Facenet+MLP Mean Precision:  %0.3f, Mean Recall:  %0.3f, Mean Accuracy:  %0.3f" % ( np.mean(precs_facenet_mlp) , np.mean(recs_facenet_mlp) , np.mean(acc_facenet_mlp) ))
# Out:
# +++++++++++++++++++++++++++++++++++++++++++
#
# *********************
# Fold 1
#
# HOG
# SVC Normalization...
# SVC training...
# done in 7.993s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.005)
# Predicting
# done in 0.049s
#
# HOG + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.53      0.62      0.57       192
#         real       0.60      0.51      0.55       217
#
#     accuracy                           0.56       409
#    macro avg       0.57      0.57      0.56       409
# weighted avg       0.57      0.56      0.56       409
#
# Confussion matrix:
# [[119  73]
#  [106 111]]
# RandomForestClassifier Normalization...
# RandomForestClassifier training...
# done in 12.098s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=200)
# Predicting
# done in 0.030s
#
# HOG + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.53      0.47      0.50       192
#         real       0.57      0.63      0.60       217
#
#     accuracy                           0.55       409
#    macro avg       0.55      0.55      0.55       409
# weighted avg       0.55      0.55      0.55       409
#
# Confussion matrix:
# [[ 90 102]
#  [ 81 136]]
# MLPClassifier Normalization...
# MLPClassifier training...
# done in 389.250s
# Best estimator found by grid search:
# MLPClassifier(hidden_layer_sizes=200)
# Predicting
# done in 0.001s
#
# HOG + MLP Metrics
#               precision    recall  f1-score   support
#
#         fake       0.54      0.47      0.50       192
#         real       0.58      0.65      0.61       217
#
#     accuracy                           0.56       409
#    macro avg       0.56      0.56      0.56       409
# weighted avg       0.56      0.56      0.56       409
#
# Confussion matrix:
# [[ 90 102]
#  [ 76 141]]
#
# LBP
# SVC Normalization...
# SVC training...
# done in 35.032s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.225s
#
# LBP + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.50      0.55      0.53       192
#         real       0.57      0.52      0.54       217
#
#     accuracy                           0.53       409
#    macro avg       0.53      0.53      0.53       409
# weighted avg       0.54      0.53      0.53       409
#
# Confussion matrix:
# [[106  86]
#  [105 112]]
# RandomForestClassifier Normalization...
# RandomForestClassifier training...
# done in 30.994s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=150)
# Predicting
# done in 0.025s
#
# LBP + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.56      0.50      0.53       192
#         real       0.60      0.65      0.62       217
#
#     accuracy                           0.58       409
#    macro avg       0.58      0.58      0.58       409
# weighted avg       0.58      0.58      0.58       409
#
# Confussion matrix:
# [[ 96  96]
#  [ 75 142]]
# MLPClassifier Normalization...
# MLPClassifier training...
# done in 1007.473s
# Best estimator found by grid search:
# MLPClassifier(hidden_layer_sizes=100, max_iter=350, solver='sgd')
# Predicting
# done in 0.001s
#
# LBP + MLP Metrics
#               precision    recall  f1-score   support
#
#         fake       0.53      0.50      0.52       192
#         real       0.58      0.61      0.60       217
#
#     accuracy                           0.56       409
#    macro avg       0.56      0.56      0.56       409
# weighted avg       0.56      0.56      0.56       409
#
# Confussion matrix:
# [[ 96  96]
#  [ 84 133]]
#
# Deepface/Facenet
# SVC Normalization...
# SVC training...
# done in 23.647s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.005)
# Predicting
# done in 0.067s
#
# Deepface/Facenet + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.58      0.57      0.58       192
#         real       0.63      0.64      0.63       217
#
#     accuracy                           0.61       409
#    macro avg       0.60      0.60      0.60       409
# weighted avg       0.61      0.61      0.61       409
#
# Confussion matrix:
# [[110  82]
#  [ 79 138]]
# RandomForestClassifier Normalization...
# RandomForestClassifier training...
# done in 22.085s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=200)
# Predicting
# done in 0.032s
#
# Deepface/Facenet + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.60      0.49      0.54       192
#         real       0.61      0.71      0.66       217
#
#     accuracy                           0.61       409
#    macro avg       0.61      0.60      0.60       409
# weighted avg       0.61      0.61      0.60       409
#
# Confussion matrix:
# [[ 94  98]
#  [ 62 155]]
# MLPClassifier Normalization...
# MLPClassifier training...
# done in 1131.598s
# Best estimator found by grid search:
# MLPClassifier(hidden_layer_sizes=150, max_iter=350, solver='sgd')
# Predicting
# done in 0.001s
#
# Deepface/Facenet + MLP Metrics
#               precision    recall  f1-score   support
#
#         fake       0.59      0.54      0.56       192
#         real       0.62      0.67      0.65       217
#
#     accuracy                           0.61       409
#    macro avg       0.61      0.60      0.60       409
# weighted avg       0.61      0.61      0.61       409
#
# Confussion matrix:
# [[103  89]
#  [ 71 146]]
# *********************
# Fold 2
#
# HOG
# SVC Normalization...
# SVC training...
# done in 8.254s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.001)
# Predicting
# done in 0.051s
#
# HOG + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.53      0.57      0.55       192
#         real       0.59      0.56      0.57       216
#
#     accuracy                           0.56       408
#    macro avg       0.56      0.56      0.56       408
# weighted avg       0.57      0.56      0.56       408
#
# RandomForestClassifier Normalization...
# RandomForestClassifier training...
# done in 12.819s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=150)
# Predicting
# done in 0.024s
#
# HOG + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.57      0.50      0.53       192
#         real       0.60      0.67      0.63       216
#
#     accuracy                           0.59       408
#    macro avg       0.59      0.59      0.58       408
# weighted avg       0.59      0.59      0.59       408
#
# MLPClassifier Normalization...
# MLPClassifier training...
# done in 868.725s
# Best estimator found by grid search:
# MLPClassifier(hidden_layer_sizes=150)
# Predicting
# done in 0.003s
#
# HOG + MLP Metrics
#               precision    recall  f1-score   support
#
#         fake       0.56      0.52      0.54       192
#         real       0.60      0.64      0.62       216
#
#     accuracy                           0.58       408
#    macro avg       0.58      0.58      0.58       408
# weighted avg       0.58      0.58      0.58       408
#
#
# LBP
# SVC Normalization...
# SVC training...
# done in 41.437s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.250s
#
# LBP + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.56      0.57      0.57       192
#         real       0.61      0.60      0.61       216
#
#     accuracy                           0.59       408
#    macro avg       0.59      0.59      0.59       408
# weighted avg       0.59      0.59      0.59       408
#
# RandomForestClassifier Normalization...
# RandomForestClassifier training...
# done in 31.946s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=150)
# Predicting
# done in 0.024s
#
# LBP + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.64      0.52      0.57       192
#         real       0.63      0.74      0.68       216
#
#     accuracy                           0.64       408
#    macro avg       0.64      0.63      0.63       408
# weighted avg       0.64      0.64      0.63       408
#
# MLPClassifier Normalization...
# MLPClassifier training...
# done in 2170.498s
# Best estimator found by grid search:
# MLPClassifier(hidden_layer_sizes=150, max_iter=300, solver='sgd')
# Predicting
# done in 0.005s
#
# LBP + MLP Metrics
#               precision    recall  f1-score   support
#
#         fake       0.54      0.47      0.50       192
#         real       0.58      0.64      0.61       216
#
#     accuracy                           0.56       408
#    macro avg       0.56      0.56      0.56       408
# weighted avg       0.56      0.56      0.56       408
#
#
# Deepface/Facenet
# SVC Normalization...
# SVC training...
# done in 25.646s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.005)
# Predicting
# done in 0.071s
#
# Deepface/Facenet + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.57      0.62      0.59       192
#         real       0.63      0.57      0.60       216
#
#     accuracy                           0.60       408
#    macro avg       0.60      0.60      0.60       408
# weighted avg       0.60      0.60      0.60       408
#
# RandomForestClassifier Normalization...
# RandomForestClassifier training...
# done in 23.596s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=200)
# Predicting
# done in 0.032s
#
# Deepface/Facenet + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.57      0.42      0.48       192
#         real       0.58      0.71      0.64       216
#
#     accuracy                           0.58       408
#    macro avg       0.57      0.57      0.56       408
# weighted avg       0.57      0.58      0.57       408
#
# MLPClassifier Normalization...
# MLPClassifier training...
# done in 617.612s
# Best estimator found by grid search:
# MLPClassifier(hidden_layer_sizes=100, max_iter=400, solver='sgd')
# Predicting
# done in 0.001s
#
# Deepface/Facenet + MLP Metrics
#               precision    recall  f1-score   support
#
#         fake       0.61      0.48      0.53       192
#         real       0.61      0.72      0.66       216
#
#     accuracy                           0.61       408
#    macro avg       0.61      0.60      0.60       408
# weighted avg       0.61      0.61      0.60       408
#
# *********************
# Fold 3
#
# HOG
# SVC Normalization...
# SVC training...
# done in 7.201s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.050s
#
# HOG + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.55      0.58      0.56       192
#         real       0.61      0.58      0.60       216
#
#     accuracy                           0.58       408
#    macro avg       0.58      0.58      0.58       408
# weighted avg       0.58      0.58      0.58       408
#
# RandomForestClassifier Normalization...
# RandomForestClassifier training...
# done in 11.100s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=200)
# Predicting
# done in 0.020s
#
# HOG + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.53      0.49      0.51       192
#         real       0.58      0.62      0.60       216
#
#     accuracy                           0.56       408
#    macro avg       0.56      0.55      0.55       408
# weighted avg       0.56      0.56      0.56       408
#
# MLPClassifier Normalization...
# MLPClassifier training...
# done in 275.969s
# Best estimator found by grid search:
# MLPClassifier(hidden_layer_sizes=100, max_iter=250)
# Predicting
# done in 0.001s
#
# HOG + MLP Metrics
#               precision    recall  f1-score   support
#
#         fake       0.54      0.54      0.54       192
#         real       0.59      0.59      0.59       216
#
#     accuracy                           0.57       408
#    macro avg       0.56      0.56      0.56       408
# weighted avg       0.57      0.57      0.57       408
#
#
# LBP
# SVC Normalization...
# SVC training...
# done in 28.116s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.180s
#
# LBP + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.54      0.55      0.55       192
#         real       0.59      0.58      0.59       216
#
#     accuracy                           0.57       408
#    macro avg       0.57      0.57      0.57       408
# weighted avg       0.57      0.57      0.57       408
#
# RandomForestClassifier Normalization...
# RandomForestClassifier training...
# done in 26.630s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=150)
# Predicting
# done in 0.030s
#
# LBP + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.57      0.47      0.52       192
#         real       0.59      0.69      0.64       216
#
#     accuracy                           0.59       408
#    macro avg       0.58      0.58      0.58       408
# weighted avg       0.58      0.59      0.58       408
#
# MLPClassifier Normalization...
# MLPClassifier training...
# done in 760.370s
# Best estimator found by grid search:
# MLPClassifier(hidden_layer_sizes=200, max_iter=400, solver='sgd')
# Predicting
# done in 0.002s
#
# LBP + MLP Metrics
#               precision    recall  f1-score   support
#
#         fake       0.60      0.53      0.56       192
#         real       0.62      0.68      0.65       216
#
#     accuracy                           0.61       408
#    macro avg       0.61      0.61      0.61       408
# weighted avg       0.61      0.61      0.61       408
#
#
# Deepface/Facenet
# SVC Normalization...
# SVC training...
# done in 21.492s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.01)
# Predicting
# done in 0.050s
#
# Deepface/Facenet + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.55      0.51      0.53       192
#         real       0.59      0.63      0.61       216
#
#     accuracy                           0.57       408
#    macro avg       0.57      0.57      0.57       408
# weighted avg       0.57      0.57      0.57       408
#
# RandomForestClassifier Normalization...
# RandomForestClassifier training...
# done in 19.580s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=200)
# Predicting
# done in 0.020s
#
# Deepface/Facenet + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.55      0.42      0.48       192
#         real       0.58      0.70      0.63       216
#
#     accuracy                           0.57       408
#    macro avg       0.57      0.56      0.56       408
# weighted avg       0.57      0.57      0.56       408
#
# MLPClassifier Normalization...
# MLPClassifier training...
# done in 498.273s
# Best estimator found by grid search:
# MLPClassifier(hidden_layer_sizes=100, max_iter=400)
# Predicting
# done in 0.002s
#
# Deepface/Facenet + MLP Metrics
#               precision    recall  f1-score   support
#
#         fake       0.56      0.57      0.56       192
#         real       0.61      0.60      0.60       216
#
#     accuracy                           0.58       408
#    macro avg       0.58      0.58      0.58       408
# weighted avg       0.58      0.58      0.58       408
#
# *********************
# Fold 4
#
# HOG
# SVC Normalization...
# SVC training...
# done in 7.221s
# Best estimator found by grid search:
# SVC(C=5000.0, class_weight='balanced', gamma=0.005)
# Predicting
# done in 0.040s
#
# HOG + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.54      0.58      0.56       192
#         real       0.60      0.55      0.57       216
#
#     accuracy                           0.57       408
#    macro avg       0.57      0.57      0.57       408
# weighted avg       0.57      0.57      0.57       408
#
# RandomForestClassifier Normalization...
# RandomForestClassifier training...
# done in 10.550s
# Best estimator found by grid search:
# RandomForestClassifier()
# Predicting
# done in 0.010s
#
# HOG + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.49      0.40      0.44       192
#         real       0.54      0.63      0.58       216
#
#     accuracy                           0.52       408
#    macro avg       0.52      0.52      0.51       408
# weighted avg       0.52      0.52      0.52       408
#
# MLPClassifier Normalization...
# MLPClassifier training...
# done in 279.093s
# Best estimator found by grid search:
# MLPClassifier(hidden_layer_sizes=150, max_iter=400)
# Predicting
# done in 0.001s
#
# HOG + MLP Metrics
#               precision    recall  f1-score   support
#
#         fake       0.54      0.49      0.51       192
#         real       0.58      0.63      0.60       216
#
#     accuracy                           0.56       408
#    macro avg       0.56      0.56      0.56       408
# weighted avg       0.56      0.56      0.56       408
#
#
# LBP
# SVC Normalization...
# SVC training...
# done in 28.415s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.170s
#
# LBP + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.54      0.60      0.57       192
#         real       0.61      0.55      0.58       216
#
#     accuracy                           0.57       408
#    macro avg       0.57      0.57      0.57       408
# weighted avg       0.58      0.57      0.57       408
#
# RandomForestClassifier Normalization...
# RandomForestClassifier training...
# done in 26.720s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=150)
# Predicting
# done in 0.020s
#
# LBP + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.59      0.49      0.54       192
#         real       0.61      0.70      0.65       216
#
#     accuracy                           0.60       408
#    macro avg       0.60      0.60      0.60       408
# weighted avg       0.60      0.60      0.60       408
#
# MLPClassifier Normalization...
# MLPClassifier training...
# done in 754.156s
# Best estimator found by grid search:
# MLPClassifier(hidden_layer_sizes=100, max_iter=300, solver='sgd')
# Predicting
# done in 0.000s
#
# LBP + MLP Metrics
#               precision    recall  f1-score   support
#
#         fake       0.58      0.55      0.56       192
#         real       0.62      0.65      0.63       216
#
#     accuracy                           0.60       408
#    macro avg       0.60      0.60      0.60       408
# weighted avg       0.60      0.60      0.60       408
#
#
# Deepface/Facenet
# SVC Normalization...
# SVC training...
# done in 20.706s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.005)
# Predicting
# done in 0.060s
#
# Deepface/Facenet + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.59      0.58      0.58       192
#         real       0.63      0.64      0.63       216
#
#     accuracy                           0.61       408
#    macro avg       0.61      0.61      0.61       408
# weighted avg       0.61      0.61      0.61       408
#
# RandomForestClassifier Normalization...
# RandomForestClassifier training...
# done in 19.120s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=150)
# Predicting
# done in 0.020s
#
# Deepface/Facenet + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.58      0.43      0.50       192
#         real       0.59      0.72      0.65       216
#
#     accuracy                           0.59       408
#    macro avg       0.58      0.58      0.57       408
# weighted avg       0.58      0.59      0.58       408
#
# MLPClassifier Normalization...
# MLPClassifier training...
# done in 812.942s
# Best estimator found by grid search:
# MLPClassifier(hidden_layer_sizes=150, max_iter=250)
# Predicting
# done in 0.003s
#
# Deepface/Facenet + MLP Metrics
#               precision    recall  f1-score   support
#
#         fake       0.58      0.48      0.53       192
#         real       0.60      0.69      0.64       216
#
#     accuracy                           0.59       408
#    macro avg       0.59      0.59      0.59       408
# weighted avg       0.59      0.59      0.59       408
#
# *********************
# Fold 5
#
# HOG
# SVC Normalization...
# SVC training...
# done in 8.291s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.005)
# Predicting
# done in 0.050s
#
# HOG + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.51      0.61      0.56       192
#         real       0.58      0.48      0.53       216
#
#     accuracy                           0.54       408
#    macro avg       0.55      0.55      0.54       408
# weighted avg       0.55      0.54      0.54       408
#
# RandomForestClassifier Normalization...
# RandomForestClassifier training...
# done in 12.677s
# Best estimator found by grid search:
# RandomForestClassifier()
# Predicting
# done in 0.016s
#
# HOG + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.54      0.54      0.54       192
#         real       0.59      0.59      0.59       216
#
#     accuracy                           0.56       408
#    macro avg       0.56      0.56      0.56       408
# weighted avg       0.56      0.56      0.56       408
#
# MLPClassifier Normalization...
# MLPClassifier training...
# done in 906.525s
# Best estimator found by grid search:
# MLPClassifier(hidden_layer_sizes=100, max_iter=300)
# Predicting
# done in 0.001s
#
# HOG + MLP Metrics
#               precision    recall  f1-score   support
#
#         fake       0.54      0.56      0.55       192
#         real       0.59      0.57      0.58       216
#
#     accuracy                           0.57       408
#    macro avg       0.57      0.57      0.57       408
# weighted avg       0.57      0.57      0.57       408
#
#
# LBP
# SVC Normalization...
# SVC training...
# done in 44.914s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.0001)
# Predicting
# done in 0.270s
#
# LBP + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.53      0.55      0.54       192
#         real       0.58      0.56      0.57       216
#
#     accuracy                           0.56       408
#    macro avg       0.56      0.56      0.56       408
# weighted avg       0.56      0.56      0.56       408
#
# RandomForestClassifier Normalization...
# RandomForestClassifier training...
# done in 33.286s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=150)
# Predicting
# done in 0.026s
#
# LBP + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.60      0.45      0.52       192
#         real       0.60      0.73      0.66       216
#
#     accuracy                           0.60       408
#    macro avg       0.60      0.59      0.59       408
# weighted avg       0.60      0.60      0.59       408
#
# MLPClassifier Normalization...
# MLPClassifier training...
# done in 2374.487s
# Best estimator found by grid search:
# MLPClassifier(hidden_layer_sizes=100, max_iter=350, solver='sgd')
# Predicting
# done in 0.002s
#
# LBP + MLP Metrics
#               precision    recall  f1-score   support
#
#         fake       0.56      0.51      0.53       192
#         real       0.59      0.64      0.62       216
#
#     accuracy                           0.58       408
#    macro avg       0.58      0.57      0.57       408
# weighted avg       0.58      0.58      0.58       408
#
#
# Deepface/Facenet
# SVC Normalization...
# SVC training...
# done in 24.484s
# Best estimator found by grid search:
# SVC(C=1000.0, class_weight='balanced', gamma=0.005)
# Predicting
# done in 0.069s
#
# Deepface/Facenet + SVM Metrics
#               precision    recall  f1-score   support
#
#         fake       0.57      0.59      0.58       192
#         real       0.62      0.60      0.61       216
#
#     accuracy                           0.60       408
#    macro avg       0.59      0.60      0.59       408
# weighted avg       0.60      0.60      0.60       408
#
# RandomForestClassifier Normalization...
# RandomForestClassifier training...
# done in 22.632s
# Best estimator found by grid search:
# RandomForestClassifier(n_estimators=150)
# Predicting
# done in 0.026s
#
# Deepface/Facenet + RF Metrics
#               precision    recall  f1-score   support
#
#         fake       0.56      0.45      0.50       192
#         real       0.58      0.68      0.63       216
#
#     accuracy                           0.57       408
#    macro avg       0.57      0.57      0.56       408
# weighted avg       0.57      0.57      0.57       408
#
# MLPClassifier Normalization...
# MLPClassifier training...
# done in 1476.517s
# Best estimator found by grid search:
# MLPClassifier(hidden_layer_sizes=100, max_iter=250)
# Predicting
# done in 0.001s
#
# Deepface/Facenet + MLP Metrics
#               precision    recall  f1-score   support
#
#         fake       0.60      0.55      0.57       192
#         real       0.62      0.67      0.65       216
#
#     accuracy                           0.61       408
#    macro avg       0.61      0.61      0.61       408
# weighted avg       0.61      0.61      0.61       408
#
#
# ********K-FOLD SUMMARY*********
# HOG+SVM Mean Precision:  0.598, Mean Recall:  0.537, Mean Accuracy:  0.563
# LBP+SVM Mean Precision:  0.593, Mean Recall:  0.562, Mean Accuracy:  0.564
# Facenet+SVM Mean Precision:  0.620, Mean Recall:  0.616, Mean Accuracy:  0.596
# HOG+RF Mean Precision:  0.576, Mean Recall:  0.627, Mean Accuracy:  0.558
# LBP+RF Mean Precision:  0.607, Mean Recall:  0.702, Mean Accuracy:  0.602
# Facenet+RF Mean Precision:  0.588, Mean Recall:  0.706, Mean Accuracy:  0.583
# HOG+MLP Mean Precision:  0.589, Mean Recall:  0.615, Mean Accuracy:  0.569
# LBP+MLP Mean Precision:  0.598, Mean Recall:  0.645, Mean Accuracy:  0.582
# Facenet+MLP Mean Precision:  0.613, Mean Recall:  0.671, Mean Accuracy:  0.601
